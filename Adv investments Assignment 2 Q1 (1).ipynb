# %%
import pandas_datareader.data as reader
import pandas as pd
import datetime as dt
from dateutil.relativedelta import relativedelta
import sqlalchemy
import yfinance as yf
import numpy as np 
import csv

# %%
#First thing is to compute the summary stats of the 25 portfolios

# %%
start = dt.datetime(1965,1,1) #these define the starting and closing time frames, we exclude the most resent year.
end = dt.datetime(2021,12,30)

# %%
ports_25 = pd.read_csv('25_Portfolios_5x5.csv', skiprows=15)

# %%
ports_25 = ports_25.rename(columns={'Unnamed: 0': 'Date'}) #Change column name to date so we can use only important rows
#ports_25['Date'] = pd.to_datetime(ports_25['Date'])
ports_25 = ports_25.set_index('Date')
ports_25 = ports_25.dropna()
ports_25
# Out:
#        SMALL LoBM    ME1 BM2    ME1 BM3    ME1 BM4 SMALL HiBM    ME2 BM1  \
# Date
# 192607     5.8248    -1.7006     0.4875    -1.4580     2.0534     1.2077
# 192608    -2.0206    -8.0282     1.3796     1.4606     8.3968     2.3618
# 192609    -4.8291    -2.6154    -4.3417    -3.2729     0.8649    -2.6540
# 192610    -9.3729    -3.5519    -3.4948     3.4413    -2.5476    -2.8069
# 192611     5.5888     4.1877     2.4623    -4.4494     0.5362     3.1033
# ...           ...        ...        ...        ...        ...        ...
# 202205     0.4125     0.3582     0.1458     0.0682     0.0441     0.4080
# 202206     0.3825     0.3264     0.1458     0.0639     0.0371     0.4056
# 202207     0.2736     0.3892     0.4023     0.4027     0.1604     0.3073
# 202208     0.2677     0.3991     0.4013     0.4414     0.1569     0.3225
# 202209     0.2492     0.4266     0.3933     0.4214     0.1544     0.3041
#
#           ME2 BM2    ME2 BM3    ME2 BM4    ME2 BM5  ...    ME4 BM1    ME4 BM2  \
# ...

# %%
ports_25 = ports_25.iloc[462:-9, :]
ports_25
# Out:
#        SMALL LoBM    ME1 BM2    ME1 BM3    ME1 BM4 SMALL HiBM    ME2 BM1  \
# Date
# 196501     8.4547     6.3220     6.7925     6.6756     8.8894     7.8767
# 196502     1.8631     0.4937     2.7483     3.2606     3.6912     3.3729
# 196503     1.6603     2.3560     1.2940     2.5157     3.2649     2.0932
# 196504     4.0673     4.4088     4.5002     4.4508     4.6372     0.1507
# 196505    -0.4533    -2.6027    -0.7366    -0.7971    -1.1928     1.0558
# ...           ...        ...        ...        ...        ...        ...
# 202108     0.4182     0.4764     0.2187     0.1170     0.0733     0.5235
# 202109     0.4181     0.4949     0.2369     0.1228     0.0727     0.5372
# 202110     0.4184     0.4925     0.2356     0.1048     0.0681     0.5427
# 202111     0.4270     0.4642     0.2270     0.1000     0.0681     0.5034
# 202112     0.4619     0.4556     0.2158     0.1017     0.0737     0.4697
#
#           ME2 BM2    ME2 BM3    ME2 BM4    ME2 BM5  ...    ME4 BM1    ME4 BM2  \
# ...

# %%
means = ports_25[:]
std = ports_25.std()
# Out:
# C:\Users\eduar\AppData\Local\Temp\ipykernel_3848\3448184130.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   means = ports_25[:].mean()
# C:\Users\eduar\AppData\Local\Temp\ipykernel_3848\3448184130.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   std = ports_25.std()

# %%
means
# Out:
# Series([], dtype: float64)
